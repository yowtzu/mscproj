# %%
get_ipython().magic('matplotlib inline')
# import logging

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.debug("test")

from pylab import *
from pandas.io.data import *
from pandas import *
from pandas.tools.plotting import *

# import libraries

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, linalg
from numpy import zeros, ones, eye, identity, cos, sqrt, exp, sum, prod, arange, pi, diag
from numpy.linalg import inv
import itertools
import timeit
import pickle


class DaxSmallModel:
    #'CVX', 'UTX', 'XOM'
    
    # symbols = ['IBM', 'MMM', 'CVX', 'UTX', 'XOM', 'MCD', 'JNJ', 'KO', 'PG', 'WMT'] # , List of all stock symbols to download #'JNJ', 'MCD'
    symbols = ["ADS.DE","ALV.DE","BAS.DE","BAYN.DE","BEI.DE","BMW.DE","CBK.DE","CON.DE","DAI.DE","DB1.DE","DBK.DE","DPW.DE","DTE.DE","EOAN.DE","FME.DE","FRE.DE","HEI.DE","HEN3.DE","IFX.DE","LHA.DE","LIN.DE","LXS.DE","MRK.DE","MUV2.DE","RWE.DE","SAP.DE","SDF.DE","SIE.DE","TKA.DE","VOW3.DE"]
    symbols = ["BAYN.DE", "SIE.DE","BAS.DE","DAI.DE", "ALV.DE", "SAP.DE"] #, "DTE.DE", "DBK.DE"]
    
    startDate =  '07/01/2013'
    endDate = '07/30/2014'
    offset = 128
    
    def __init__(self):
        self.__download_data()
        self.__extract_data()

    def __download_data(self):
        logging.debug('Reading stock data from Yahoo Finance')
        # extra half a year to warm EWMA up for historical vol calc
        #self.stock_data = DataReader(self.symbols, 'yahoo', start='07/01/2009',end='06/30/2012') # Download data from YAHOO as a pandas Panel object
        self.stock_data = DataReader(self.symbols, "yahoo", start=self.startDate,end=self.endDate)
                                     
    def __extract_data(self):
        offset = self.offset
        logging.debug('Extracting and plotting Adjusted Closing Prices')
        self.adj_close  = self.stock_data['Adj Close']   
        self.index_close = DataReader("^GDAXI", "yahoo", start=self.startDate,end=self.endDate)['Adj Close']

        self.adj_close = concat([self.adj_close,DataFrame(self.index_close)], axis=1)
        self.adj_close = self.adj_close[np.isfinite(self.adj_close['Adj Close'])]     
        self.adj_close = self.adj_close.drop("Adj Close", 1)
        # Pull out adjusted closing prices as pandas DataFrane object
        self.index_close = self.index_close
        #self.index_close = .4 * self.adj_close["BAYN.DE"] + .3 * self.adj_close["SIE.DE"] + .2 * self.adj_close["BAS.DE"] + .1 * self.adj_close["DAI.DE"]
        self.adj_close = concat([self.adj_close,DataFrame(self.index_close)], axis=1)
     
        #self.adj_close.plot(title='Daily Adjusted Closing Prices for 401K Funds')
        #show()
        
        self.returns = self.adj_close.pct_change()
        self.returns = self.adj_close - self.adj_close.shift(1) 
        
        self.index_returns = self.index_close - self.index_close.shift(1)
        #self.returns.plot(title='Arithmetric Daily Returns')
        #show()
        #plot(rolling_std(returns.IBM, window=25))
        #show()
        #plot(ewma(returns**2, com=0.94/(1-0.94)))
        
        # ewma mean of the price (drop the last column)
        self.price_ewma_mean = ewma(self.adj_close[self.adj_close.columns[:-1]], com=0.94/(1-0.94))
        self.price_ewma_mean = self.price_ewma_mean[offset:].values

        # ewma cov of the price (drop the last column)
        res = zeros(shape=(len(self.symbols), len(self.symbols), len(self.adj_close)))
        for (i, sym1) in enumerate(self.adj_close.columns[:-1]):
            for (j, sym2) in enumerate(self.adj_close.columns[:-1]):
                res[i,j] = ewmcov(self.adj_close[sym1], self.adj_close[sym2], com=0.94/(1-0.94)).values
        
        self.price_ewma_cov = res[:,:,128:]
        self.price_ewma_cov = transpose(self.price_ewma_cov, [2,0,1])    
        self.adj_close = self.adj_close[offset:]
        
        # ewma mean of the return (drop the last column)
        self.ewma_mean = ewma(self.returns[self.returns.columns[:-1]], com=0.94/(1-0.94))[offset:].values
        
        self.index_ewma_mean = ewma(self.index_returns, com=0.94/(1-0.94))[offset:].values
        
        # ewma cov of the return (drop the last column)
        res = zeros((len(self.symbols), len(self.symbols), len(self.returns)))
        for (i, sym1) in enumerate(self.returns.columns[:-1]):
            for (j, sym2) in enumerate(self.returns.columns[:-1]):
                res[i,j] = ewmcov(self.returns[sym1], self.returns[sym2], com=0.94/(1-0.94)).values
        self.ewma_cov = res[:,:,128:]
        self.ewma_cov = transpose(self.ewma_cov, [2,0,1])
        
        # realign the data properly to start from 2010/01/01
        #self.ewma_cor = self.ewma_cor["2010/01/01":]
        self.returns = self.returns[offset:]
        self.index_returns = self.index_returns[offset:]
        #logging.debug(self.ewma_cov.shape)
        #logging.debug(self.ewma_cov[1:5])
        #logging.debug(self.returns.shape)
        #logging.debug(self.returns[1:5])
        #ewmcorr(arg1=returns, arg2=returns, com=0.94/(1-0.94), pairwise = True)
        #plot(-sqrt(ewma(returns.IBM**2, com=0.94/(1-0.94))))
        
    def __plot_extra():
        """
        Create a scatter plot of mean return vs. standard deviation (a measure of volatility)
        for each stock. We would expect that the mean return would increase with volatility,
        but this is not always the case.
        """
        mean_ret   = returns.mean() # Returns a pandas DataFrame with mean values indexed by stock symbol
        std_ret    = returns.std()  # Returns a pandas DataFrame with standard deviations (volatility) indexed by stock symbol
        plot(std_ret,mean_ret,'ro')
        for ii in range(len(symbols)):
            annotate(mean_ret.index[ii],(std_ret[ii],mean_ret[ii])) # Annotate the markers with the stock symbol
        title('Mean Daily Return vs. Standard Deviation for 401K Funds')
        xlabel('Standard Deviation of Daily Returns')
        ylabel('Mean of Daily Returns')
        show()
        """
        Now create a boxplot as another means to visualize volatility in a stock. Note that the 
        boxplot gets pretty busy for more than a handful of stocks
        """

        returns.boxplot()
        title('Selected 401K Funds Daily Returns')
        show()

        """
        Finally calculate the correlation matrix between the various stocks. This returns a DataFrame
        object with rows and columns labeled with the stock symbols.  It's actually fairly clever
        because it automatically handles the fact that not all the symbols have data available on the
        same day.
        The values method returns just the array of data
        """

        sel_corr=returns.corr()     # Calculate correlation
        sel_corr_values=sel_corr.values # Return just the array of correlation data (no labels)
        print(sel_corr_values)
    
        """
        Now create a scatter plot matrix. This shows a probability density on each diagonal and
        a scatter plot indicating correlation on the off-diagonals
        """


        scatter_matrix(returns, alpha=0.2, figsize=(6,6), diagonal='kde')
        show()

dax = DaxSmallModel()
# Out:
# DEBUG:root:test
# DEBUG:root:Reading stock data from Yahoo Finance
# DEBUG:root:Extracting and plotting Adjusted Closing Prices

# %%
# experiment parameters
reps = 30
N = 10000

# model parameters
n_x = n_u = number_sources = len(dax.symbols)
n_y = 1
T = 125
W = 5+np.zeros(T, dtype="int")[::-1]

# gamma is an increasing sequence
#gamma=log(arange(2,T+2))
gamma=100*ones(T)
# matrices cost L1 higher, mean action penalty, could be used to model transaction cost
#L1=100*diag(arange(1,number_sources+1)[::-1])  # continuous action penalty
L1=10*eye(number_sources)
# resample helper function given the index
def resample(data, indices, fromIndex, toIndexExclusive):
    data[fromIndex:toIndexExclusive,:] = data[fromIndex:toIndexExclusive,indices]

def sample_proposal_u(u1_old, gamma):
    """ U_t | U_t-1 """
    u1 = stats.uniform.rvs(0.0, 1.0, size=[1,n_u])
    return u1

# to store result
results = dict() 
for rep in range(reps):
    np.random.seed(7+rep)
    logging.debug("rep: %i", rep)

    ymean = zeros((T, 1, n_y))
    yvar = zeros((T, n_y, n_y))
    u_opt = zeros((T, 1, n_x)) 
        
    # need to offset T time to completely show MPC
    for offset in range(T):
        logging.debug("time step: %i and window size: %i" , offset, W[offset])
        # target ref model y^ref, return mean and cov
    
        #y = dax.adj_close["Adj Close"][offset:offset+W[offset]].reshape(W[offset],1,1) # make sure they are matrix after all
        # EWMA
        y = (dax.adj_close["Adj Close"][offset] + dax.index_ewma_mean[offset]*np.arange(W[offset])).reshape(W[offset],1,1)
        
        x_mean = dax.ewma_mean[offset:offset+W[offset]]
        x_ewma_cov = dax.ewma_cov[offset:offset+W[offset]]
        # construct yref here based on x_mean and model
        
        # initialise parameters
        u1 = zeros(shape=(W[offset], N, 1, number_sources)) # make sure they are matrix after all
        if offset == 0:
            u1[-1] = sample_proposal_u(0, gamma[offset]) # u_old is not important actually
        else:
            u1[-1] = u_opt[offset-1]
        # cost
        rec_true = zeros(shape=(W[offset],N)) 
        rec2 = zeros(shape=(W[offset],N))
        # y mean and variance
        RecLikeMean=zeros(shape=(W[offset], N, 1, n_y))
        RecLikeVar=zeros(shape=(W[offset],N, 1, n_y))
        weight=zeros(shape=(W[offset],N))
        
        # Kalman filter
        mu=zeros(shape=(W[offset],N, n_x, 1))
        for i in range(N):
            mu[-1,i] = dax.adj_close[:1].values[0,0:n_u].reshape(n_u,1)
        Sigma=zeros(shape=(W[offset], N, n_x, n_x))
        start = timeit.default_timer()           
        for t in range(W[offset]):
            epsilon=gamma[t]
    
            for i in range(N):
                u1[t, i] = sample_proposal_u(u1[t-1, i], gamma[t])
                rec2[t,i] = (-0.5*epsilon*((u1[t,i]-u1[t-1,i]).dot(L1).dot((u1[t,i]-u1[t-1,i]).T))).item()

            for i in range(N):
                # c = u1[t,i].dot(diag(0.1*np.arange(1,n_u+1)[::-1]))
                c = 30*u1[t,i]
                a = eye(n_u) # diag(u1[t,i].reshape(n_x)) #diag(c[0])
                F = 0.0001*ones(n_u) # market impact
                b = linalg.sqrtm(x_ewma_cov[0])                            # hidden model noise eye(n_u) 
                d = 0.01*eye((n_y)) # linalg.sqrtm(0.01*eye((n_y, n_y)))    # y measurement noise R in kanta's model

                mu[t,i]          = a.dot(mu[t-1,i]) + F.dot((u1[t,i]-u1[t-1,i]).T) + x_mean[0].reshape(n_u, 1)
                Sigma[t,i]       = a.dot(Sigma[t-1,i]).dot(a.T)+b.dot(b.T) 
                z                = y[t].T - c.dot(mu[t,i])                                 # + G which is zero here
                SS               = c.dot(Sigma[t,i]).dot(c.T)  + d.dot(d.T)
                RecLikeMean[t,i] = c.dot(mu[t,i]) #                          + G
                RecLikeVar[t,i]  = SS
            
                K=Sigma[t,i].dot(c.T).dot(linalg.inv(SS))
                mu[t,i] = mu[t,i] + K.dot(z)
                Sigma[t,i] = (eye(n_u)-K.dot(c)).dot(Sigma[t,i])
                rec_true[t,i] = -0.5*epsilon*(y[t] - RecLikeMean[t,i]).dot(linalg.inv(SS)).dot((y[t] -RecLikeMean[t,i]).T)
            
            weight[t] = exp(rec2[t] + rec_true[t])
            #logging.debug(np.unique(weight[t]))
            #plt.hist(weight, 20)
            #show()
            #plt.hist(exp(rec2[t]), 30)
            #show()
            #print(mean(rec2[t]), mean(rec_true[t]), mean(weight))
            
            weight[t] = weight[t]/sum(weight[t])    
            indices = np.random.choice(range(N),size=N, replace=True, p=weight[t])
            
            for data in (u1, RecLikeMean, RecLikeVar, mu, Sigma, rec_true, rec2):
                resample(data, indices, 0, t+1)
        logging.debug(timeit.default_timer() - start)            
        
        # alternative calculation? normalised by gamma properly
        gamma_m = zeros(shape=(W[offset],N))
        for t in range(W[offset]):
            gamma_m[t,:] = gamma[t]

        j_opt = np.sum(np.log(weight)/gamma_m, 0)
        j = np.max(j_opt)
        j_int = np.nonzero(j_opt == j)[0][0]

        ymean[offset] = RecLikeMean[0,j_int]
        yvar[offset] = RecLikeVar[0,j_int]
        u_opt[offset] =u1[0,j_int]

    results[rep] = [u1, u_opt, rec_true, rec2, mu, Sigma, j_opt, j, j_int, ymean, yvar]
    logging.debug("result len %i", len(results))
# Out:
# DEBUG:root:rep: 0
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:23.253393616061658
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.77534110902343
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.82467971800361
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.927520846948028
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.97678284009453
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.727362681063823
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.86953699600417
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.802387039992027
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.841474174987525
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.736083267023787
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.763646617997438
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.743250312050804
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.71869571704883
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.695489418925717
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.782337215030566
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.708093210007064
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.709122747997753
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.664543193066493
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.722210988984443
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.781180260004476
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.739450479042716
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.69343621202279
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.730561251053587
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:22.645043273922056
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:22.77367740496993
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:22.741508599021472
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:22.718532396946102
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:22.754836663021706
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:22.72252330603078
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:22.81035535701085
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:22.779957340098917
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:22.763334112009034
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:22.792248110985383
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:22.74429348099511
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:22.844526747940108
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:22.797094123088755
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:22.799107908038422
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:22.783295201021247
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:22.83252192591317
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:22.890823037945665
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:22.770585256046616
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:22.790023432928137
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:22.80658361199312
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:22.736027969047427
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:22.804945228039287
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:22.753907536971383
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:22.796280369977467
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:22.714538112981245
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.81340877804905
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:22.78557598590851
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.740365032106638
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:22.78359533404
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.79975528502837
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.756006865063682
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.840419368003495
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.808099298970774
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.728601617971435
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.79286944400519
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.797321445075795
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:22.770884198951535
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:22.813936655060388
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:22.737720913020894
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.793670075945556
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:23.160985702066682
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:22.737618560087867
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:22.815510844928212
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:22.786853373982012
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:22.74093982600607
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:22.781341389054433
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:22.77903265703935
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:22.846974215004593
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:22.759322521975264
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:22.79304181097541
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:22.884196984930895
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:22.778418499045074
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:22.785294405999593
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:22.830445311963558
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:22.78067376394756
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:22.741446182015352
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:22.76174985000398
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:22.85472998698242
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:22.749167982954532
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:22.76402489398606
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:22.73015762702562
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:22.804724168032408
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:22.82305156206712
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.80131214496214
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.725443104980513
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:22.726162086008117
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:22.774169645970687
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:22.81949867203366
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:22.769717250950634
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:22.79398980503902
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.715575602022
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:22.733927519991994
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:22.79476948303636
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:22.761542022926733
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:22.75196883501485
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:22.774128981982358
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:22.782831931952387
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:22.759964035009034
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:22.74705196497962
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:22.93357929692138
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:22.73297938099131
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:22.740694395964965
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:22.744698532973416
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:22.73763569397852
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:22.82904485205654
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:22.794228696031496
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:22.815011356025934
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:22.840351051068865
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:22.824660629034042
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:22.78683135099709
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:22.79049686109647
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:22.70538346702233
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:22.75105221499689
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:22.748054220923223
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:22.736519568017684
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:22.80029253300745
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:22.76720107998699
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:22.728192833950743
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:22.780278985970654
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:22.737972779897973
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:22.74102898000274
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:22.72272428998258
# DEBUG:root:result len 1
# DEBUG:root:rep: 1
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:22.7745328679448
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.714949938002974
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.872656787978485
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.867086885962635
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.85839821503032
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.861452190903947
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.863665828946978
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.827354473993182
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.842881146003492
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.81281415198464
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.905967198079452
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.844324687030166
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.78147706098389
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.762632060912438
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.78725253196899
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.759880771976896
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.800113625009544
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.72186337597668
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.91730805602856
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.80882550298702
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.84402429300826
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.78281463100575
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.801571218995377
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:22.7551903470885
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:22.72644595906604
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:22.755264822975732
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:22.757214462966658
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:22.91371995396912
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:22.792163438978605
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:22.84242913790513
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:22.809105337015353
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:22.822059264057316
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:22.823672576923855
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:22.787619407987222
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:22.842923365999013
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:22.834928471012972
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:22.813159125042148
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:22.74357913294807
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:22.723128153011203
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:22.77817552408669
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:22.704409083002247
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:22.780062185949646
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:22.743241833057255
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:22.699138737050816
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:22.662606050027534
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:22.65792012703605
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:22.731291678966954
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:22.633956174948253
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.714160518022254
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:22.673215689021163
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.67786757205613
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:22.732908759033307
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.729092753026634
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.873856495018117
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.79203316802159
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.754134234040976
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.699455014895648
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.70051778294146
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.768932556034997
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:22.66385348897893
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:22.757591670029797
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:22.63110879191663
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.75358898099512
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:22.637467155000195
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:22.667190614971332
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:22.702509221970104
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:22.750495740910992
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:22.665835523046553
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:22.70025162701495
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:22.699241364956833
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:22.642208826029673
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:22.67783074907493
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:22.689869422931224
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:22.696599766029976
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:22.77290283702314
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:22.742498908075504
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:22.808651346014813
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:22.740836768993177
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:22.835158220957965
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:22.688906448078342
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:22.853627450065687
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:22.676719403010793
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:22.626851537032053
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:22.588223329978064
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:22.7025134380674
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:22.7078262710711
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.7605282550212
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.630392312072217
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:22.685361690004356
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:22.697066925931722
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:22.714528602082282
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:22.678000334999524
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:22.72563221596647
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.609268649946898
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:22.651146788033657
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:22.683221817947924
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:22.712966576917097
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:22.73201600392349
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:22.760616799001582
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:22.755881523014978
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:22.7713120469125
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:22.702299712924287
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:22.755778733990155
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:22.89687515294645
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:22.716947627021
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:22.66048270498868
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:22.71360402996652
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:22.716784843010828
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:22.71677922096569
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:22.704513053991832
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:22.784558457089588
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:22.78404925391078
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:22.805928147980012
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:22.69756145705469
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:22.80767439608462
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:22.74476335803047
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:22.875398625037633
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:22.693649261957034
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:22.748573003103957
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:22.754141698009335
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:22.700509254005738
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:22.71802599891089
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:22.715370197896846
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:22.66094607906416
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:22.552257654024288
# DEBUG:root:result len 2
# DEBUG:root:rep: 2
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:22.573790797032416
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.54451455909293
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.601355430902913
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.60575364495162
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.695262661087327
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.559013729915023
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.637672083918005
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.575350430910476
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.575945887016132
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.612566430005245
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.591218636953272
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.592954426072538
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.55492207291536
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.53145859099459
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.629202669020742
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.531184286111966
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.55566797789652
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.505784005043097
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.58772885403596
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.581493055913597
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.621272481046617
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.52493151696399
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.60120336408727
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:22.53670489601791
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:22.5432489879895
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:22.586256238049828
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:22.577178430045024
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:22.6152791720815
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:22.574798214947805
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:22.657967683044262
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:22.639553349930793
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:22.544816701090895
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:22.635958631057292
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:22.597115893033333
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:22.5778497220017
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:22.630912336986512
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:22.62957434100099
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:22.619265079963952
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:22.657340376987122
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:22.676782305934466
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:22.576082256040536
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:22.63739610707853
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:22.601656791055575
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:22.585695790010504
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:22.505420945002697
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:22.588957435102202
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:22.53559229709208
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:22.51888972101733
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.558760048937984
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:22.56124529906083
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.493918789085
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:22.578612905927002
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.552137188031338
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.60284856299404
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.565912212012336
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.60282486397773
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.48683763993904
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.60418504604604
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.578459382988513
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:22.565984528977424
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:22.582441976992413
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:22.54574483190663
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.588389626005664
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:22.520094050909393
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:22.522461549961008
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:22.557623837026767
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:22.5970209420193
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:22.547671642969362
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:22.583178299013525
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:22.54681123199407
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:22.511432065977715
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:22.535428075003438
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:22.576114704017527
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:22.56290466792416
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:22.596758668893017
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:22.536049233051017
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:22.56524012295995
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:22.606186329969205
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:22.535417395061813
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:22.55321618996095
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:22.555175682064146
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:22.561601763009094
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:22.519894228084013
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:22.522443364956416
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:22.53204560908489
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:22.61736746900715
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.574741055024788
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.545620391028933
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:22.516071040998213
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:22.586911607999355
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:22.582803276949562
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:22.611259032972157
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:22.586637411033735
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.551706340978853
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:22.5021939399885
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:22.535136632970534
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:22.53447211207822
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:22.547688603051938
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:22.57203338900581
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:22.560899263015017
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:22.585316488984972
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:22.51845809002407
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:22.565535828936845
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:22.544598077889532
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:22.567915395949967
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:22.4907154510729
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:22.50633903790731
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:22.516446115914732
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:22.530405038036406
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:22.55517421697732
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:22.552100155036896
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:22.552594598033465
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:22.54165098303929
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:22.52427325199824
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:22.564149958081543
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:22.525556788081303
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:22.531418055994436
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:22.53662258607801
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:22.58886832999997
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:22.570874402066693
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:22.541105246986263
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:22.5932489259867
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:22.531157494988292
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:22.514361042995006
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:22.51607796200551
# DEBUG:root:result len 3
# DEBUG:root:rep: 3
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:22.53862584300805
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.51884943502955
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.54673428402748
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.548556365072727
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.659197633969598
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.517467080033384
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.635104196961038
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.56346861901693
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.58284242497757
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.568098691059276
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.555381788988598
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.590206402004696
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.536464008037
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.55234788591042
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.5711303219432
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.539267693995498
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.513487951946445
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.42906271200627
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.58998365199659
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.560692957951687
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.589071681024507
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.516895460081287
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.593287731986493
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:22.501150297001004
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:22.469397332984954
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:22.55998549796641
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:22.483045162050985
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:22.565980955958366
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:22.480374017963186
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:22.575528934015892
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:22.56864641502034
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:22.51512563007418
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:22.556509561021812
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:22.513340909034014
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:22.589725680998527
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:22.591388483997434
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:22.60823612497188
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:22.582142028957605
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:22.60074280295521
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:22.623631384107284
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:22.53338223998435
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:22.6259972860571
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:22.554232463007793
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:22.52853029803373
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:22.50597607891541
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:22.510388508904725
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:22.52014740393497
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:22.450165492016822
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.503536880016327
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:22.495310786995105
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.535015923087485
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:22.587451028986834
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.555393747985363
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.547168581048027
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.610572698060423
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.62270259205252
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.56023417902179
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.617079103947617
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.615459434920922
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:22.541223879088648
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:22.613332369015552
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:22.570790565921925
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.661571984994225
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:22.5552988339914
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:22.592003419995308
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:22.62000158196315
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:22.589838479063474
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:22.56235431798268
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:22.5961163159227
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:22.604746606084518
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:22.52659402496647
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:22.594064328004606
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:22.566268081078306
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:22.6077203709865
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:22.582306990982033
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:22.58566160092596
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:22.566505749011412
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:22.620755544048734
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:22.560112501028925
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:22.537323747063056
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:22.59553612698801
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:22.52863461500965
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:22.54660140001215
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:22.502798527944833
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:22.615194177953526
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:22.635447663953528
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.604985032929108
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.577853354043327
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:22.537470140028745
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:22.611566249048337
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:22.58894046000205
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:22.61037116299849
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:22.650702809914947
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.527029457036406
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:22.537928563077003
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:22.563743293983862
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:22.56696619896684
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:22.573848227970302
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:22.585567328962497
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:22.582660804037005
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:22.552823978941888
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:22.599860819987953
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:22.551308981026523
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:22.544975735945627
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:22.530084943049587
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:22.551995204994455
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:22.52356607594993
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:22.553542622947134
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:22.53582255996298
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:22.537707249983214
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:22.55206727492623
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:22.559637672035024
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:22.607452688040212
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:22.562268991023302
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:22.547184632974677
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:22.53903825499583
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:22.528749010059983
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:22.567841988056898
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:22.592346637975425
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:22.626079890993424
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:22.556727801915258
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:22.589961707941256
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:22.504717460949905
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:22.528988334001042
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:22.548240405041724
# DEBUG:root:result len 4
# DEBUG:root:rep: 4
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:22.5519699890865
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.535619094967842
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.57496420003008
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.64161035604775
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.630020914948545
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.59872735699173
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.65321065997705
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.611023423960432
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.59873005701229
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.61644701298792
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.58522386290133
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.621100593940355
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.614282079972327
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.586072965990752
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.5871021830244
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.541726112016477
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.546711207018234
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.52812993398402
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.579942574957386
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.583399672992527
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.58660246594809
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.563798225019127
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.593494323897175
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:22.57136761106085
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:22.531188145047054
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:22.57543468393851
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:22.534278431907296
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:22.588256778893992
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:22.52632928302046
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:22.591895173070952
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:22.57314629596658
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:22.564193088910542
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:22.633634095080197
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:22.586332676000893
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:22.61153288197238
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:22.619183935923502
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:22.582608941942453
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:22.623729887069203
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:22.617866531014442
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:22.696762300096452
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:22.574664103914984
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:22.625180456088856
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:22.59288904396817
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:22.532709363964386
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:22.527826130972244
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:22.53760549495928
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:22.503385931951925
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:22.542436875985004
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.560492902994156
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:22.551982576027513
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.54429688793607
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:22.60324457194656
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.59082254196983
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.62669739604462
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.60423204791732
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.63564699899871
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.529553187079728
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.61055619700346
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.58103880798444
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:22.606694443966262
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:22.598154515028
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:23.234706328017637
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.699621189036407
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:22.954253330011852
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:22.821055957931094
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:22.867063159006648
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:22.724299506051466
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:22.940337717998773
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:23.003836945979856
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:22.901972671039402
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:22.846909448038787
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:22.944286874029785
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:22.91853009094484
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:23.158037691027857
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:22.623569300980307
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:23.003713346086442
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:22.863646428915672
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:22.58867804496549
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:22.54573592694942
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:22.593233631108887
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:22.58573454397265
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:22.54854513600003
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:22.55254809895996
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:22.542951308074407
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:22.526819434948266
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:22.58698265091516
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.558714346960187
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.535262821009383
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:22.51877106097527
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:22.636884437990375
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:22.57652469491586
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:22.584052763995714
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:22.557331152027473
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.519672689959407
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:22.555243898066692
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:22.603091207914986
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:22.568729687016457
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:22.605280802003108
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:22.565586337004788
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:22.630983347073197
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:22.58219221595209
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:22.5688376420876
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:22.54071698093321
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:22.55197680008132
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:22.540030904114246
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:22.5831025299849
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:22.519527849042788
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:22.588421562919393
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:22.551474350038916
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:22.58596301905345
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:22.57001751102507
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:22.5591318809893
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:22.541515511926264
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:22.550964494002983
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:22.55291131604463
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:22.592363649979234
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:22.542222161078826
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:22.564039221964777
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:22.600350660039112
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:22.634442046051845
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:22.576161912991665
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:22.635891287005506
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:22.53455143701285
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:22.56751894101035
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:22.550444112042896
# DEBUG:root:result len 5
# DEBUG:root:rep: 5
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:22.606863055960275
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:22.622244318015873
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:22.59351178095676
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:22.63506016600877
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:22.67649919493124
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:22.618838274036534
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:22.700809912057593
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:22.675418306025676
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:22.647824354004115
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:22.62700294307433
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:22.62471515708603
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:22.607010386069305
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:22.610945921042003
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:22.574727330938913
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:22.64803005196154
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:22.56461375404615
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:22.58102114906069
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:22.512334423023276
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:22.57368416094687
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:22.597009849967435
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:22.619886243948713
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:22.580818061949685
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:22.616775176953524
# ...
# DEBUG:root:23.246546379989013
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:24.65622801007703
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:24.912112308084033
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:23.68265250895638
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:24.250496470951475
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:24.289074228028767
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:23.63837672106456
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:24.37681975006126
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:23.881559220026247
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:24.731454588007182
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:24.897471028962173
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:24.499808348016813
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:23.866566273965873
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:23.65857644600328
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:22.74281282594893
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:23.07119370996952
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:22.768970682984218
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:23.06537056202069
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:22.95326241804287
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:22.927241631085053
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:22.824810643913224
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:22.79585054400377
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:22.854226824943908
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:22.96178455289919
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:22.87756172893569
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:23.277093810029328
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:23.751781573984772
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:22.90954437898472
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:22.928837543004192
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:22.77671284903772
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:24.127276710933074
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:24.44095986301545
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:23.370546365040354
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:24.200534429983236
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:24.748960983008146
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:24.264633370097727
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:23.627744563971646
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:23.050107839982957
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:23.793767794966698
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:23.636021043988876
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:24.831768429954536
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:24.64229918201454
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:23.359196411911398
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:23.60657866403926
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:24.388915819930844
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:24.040492251049727
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:24.169795542024076
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:24.10837579704821
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:23.792243673000485
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:24.20172528096009
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:24.187596296076663
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:23.255315340938978
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:22.91768392303493
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:22.990020481985994
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:23.533373608952388
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:23.80367690406274
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:23.744982701027766
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:23.875490181031637
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:23.548441746039316
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:24.923584001953714
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:23.55968751804903
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:24.49793187098112
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:24.45406014402397
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:24.420223644934595
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:23.654169352026656
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:24.241109204944223
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:24.203397349920124
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:24.344464327092282
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:23.728100531036034
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:23.985308940988034
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:24.28193379798904
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:23.69982861704193
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:23.00212024792563
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:23.133140129968524
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:24.06625345197972
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:24.55958951089997
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:24.108071096008644
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:24.82430346298497
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:24.605888952035457
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:24.63694148999639
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:23.714404241065495
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:23.76976361591369
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:23.95079278596677
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:23.548060336965136
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:23.22430393099785
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:23.493643060093746
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:23.3732634059852
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:23.211308137048036
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:23.31404721608851
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:24.887998181045987
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:23.490357842994854
# DEBUG:root:result len 29
# DEBUG:root:rep: 29
# DEBUG:root:time step: 0 and window size: 5
# DEBUG:root:24.946053272113204
# DEBUG:root:time step: 1 and window size: 5
# DEBUG:root:24.524604862905107
# DEBUG:root:time step: 2 and window size: 5
# DEBUG:root:23.218963623046875
# DEBUG:root:time step: 3 and window size: 5
# DEBUG:root:23.92182099504862
# DEBUG:root:time step: 4 and window size: 5
# DEBUG:root:24.16795390995685
# DEBUG:root:time step: 5 and window size: 5
# DEBUG:root:24.791335499030538
# DEBUG:root:time step: 6 and window size: 5
# DEBUG:root:24.003407021984458
# DEBUG:root:time step: 7 and window size: 5
# DEBUG:root:23.411786408047192
# DEBUG:root:time step: 8 and window size: 5
# DEBUG:root:23.504626902984455
# DEBUG:root:time step: 9 and window size: 5
# DEBUG:root:24.02993525704369
# DEBUG:root:time step: 10 and window size: 5
# DEBUG:root:23.63511745503638
# DEBUG:root:time step: 11 and window size: 5
# DEBUG:root:23.81760685192421
# DEBUG:root:time step: 12 and window size: 5
# DEBUG:root:25.136081637931056
# DEBUG:root:time step: 13 and window size: 5
# DEBUG:root:23.966121203033254
# DEBUG:root:time step: 14 and window size: 5
# DEBUG:root:24.428473499021493
# DEBUG:root:time step: 15 and window size: 5
# DEBUG:root:24.95383989904076
# DEBUG:root:time step: 16 and window size: 5
# DEBUG:root:24.16769541206304
# DEBUG:root:time step: 17 and window size: 5
# DEBUG:root:23.96027372905519
# DEBUG:root:time step: 18 and window size: 5
# DEBUG:root:24.11743619502522
# DEBUG:root:time step: 19 and window size: 5
# DEBUG:root:23.752682210993953
# DEBUG:root:time step: 20 and window size: 5
# DEBUG:root:23.319003619952127
# DEBUG:root:time step: 21 and window size: 5
# DEBUG:root:24.038405426079407
# DEBUG:root:time step: 22 and window size: 5
# DEBUG:root:23.663031163974665
# DEBUG:root:time step: 23 and window size: 5
# DEBUG:root:23.734058159054257
# DEBUG:root:time step: 24 and window size: 5
# DEBUG:root:24.403483387897722
# DEBUG:root:time step: 25 and window size: 5
# DEBUG:root:23.00331191904843
# DEBUG:root:time step: 26 and window size: 5
# DEBUG:root:24.824697921052575
# DEBUG:root:time step: 27 and window size: 5
# DEBUG:root:24.79576906899456
# DEBUG:root:time step: 28 and window size: 5
# DEBUG:root:23.079801428946666
# DEBUG:root:time step: 29 and window size: 5
# DEBUG:root:23.628066809964366
# DEBUG:root:time step: 30 and window size: 5
# DEBUG:root:23.604312458075583
# DEBUG:root:time step: 31 and window size: 5
# DEBUG:root:24.33518945297692
# DEBUG:root:time step: 32 and window size: 5
# DEBUG:root:23.507433135062456
# DEBUG:root:time step: 33 and window size: 5
# DEBUG:root:23.743547389050946
# DEBUG:root:time step: 34 and window size: 5
# DEBUG:root:24.079080436960794
# DEBUG:root:time step: 35 and window size: 5
# DEBUG:root:23.42666569899302
# DEBUG:root:time step: 36 and window size: 5
# DEBUG:root:24.603477244032547
# DEBUG:root:time step: 37 and window size: 5
# DEBUG:root:24.609830740024336
# DEBUG:root:time step: 38 and window size: 5
# DEBUG:root:23.599518466042355
# DEBUG:root:time step: 39 and window size: 5
# DEBUG:root:24.41718878899701
# DEBUG:root:time step: 40 and window size: 5
# DEBUG:root:23.511337311007082
# DEBUG:root:time step: 41 and window size: 5
# DEBUG:root:24.872470778995194
# DEBUG:root:time step: 42 and window size: 5
# DEBUG:root:23.155902992002666
# DEBUG:root:time step: 43 and window size: 5
# DEBUG:root:24.49241527193226
# DEBUG:root:time step: 44 and window size: 5
# DEBUG:root:24.247316839988343
# DEBUG:root:time step: 45 and window size: 5
# DEBUG:root:23.107789393980056
# DEBUG:root:time step: 46 and window size: 5
# DEBUG:root:24.140430781058967
# DEBUG:root:time step: 47 and window size: 5
# DEBUG:root:24.14096268406138
# DEBUG:root:time step: 48 and window size: 5
# DEBUG:root:24.366793034947477
# DEBUG:root:time step: 49 and window size: 5
# DEBUG:root:24.456382523989305
# DEBUG:root:time step: 50 and window size: 5
# DEBUG:root:23.28496571991127
# DEBUG:root:time step: 51 and window size: 5
# DEBUG:root:24.140266908914782
# DEBUG:root:time step: 52 and window size: 5
# DEBUG:root:23.542202810989693
# DEBUG:root:time step: 53 and window size: 5
# DEBUG:root:23.058558895951137
# DEBUG:root:time step: 54 and window size: 5
# DEBUG:root:25.05679781897925
# DEBUG:root:time step: 55 and window size: 5
# DEBUG:root:23.755339422030374
# DEBUG:root:time step: 56 and window size: 5
# DEBUG:root:23.779154838994145
# DEBUG:root:time step: 57 and window size: 5
# DEBUG:root:24.236291740089655
# DEBUG:root:time step: 58 and window size: 5
# DEBUG:root:24.18470410106238
# DEBUG:root:time step: 59 and window size: 5
# DEBUG:root:24.692545309080742
# DEBUG:root:time step: 60 and window size: 5
# DEBUG:root:24.28519416996278
# DEBUG:root:time step: 61 and window size: 5
# DEBUG:root:24.347950757015496
# DEBUG:root:time step: 62 and window size: 5
# DEBUG:root:24.190733426017687
# DEBUG:root:time step: 63 and window size: 5
# DEBUG:root:24.04925863700919
# DEBUG:root:time step: 64 and window size: 5
# DEBUG:root:24.870262842043303
# DEBUG:root:time step: 65 and window size: 5
# DEBUG:root:23.175502966041677
# DEBUG:root:time step: 66 and window size: 5
# DEBUG:root:24.903509586001746
# DEBUG:root:time step: 67 and window size: 5
# DEBUG:root:24.86875218502246
# DEBUG:root:time step: 68 and window size: 5
# DEBUG:root:25.124707537004724
# DEBUG:root:time step: 69 and window size: 5
# DEBUG:root:23.73649074905552
# DEBUG:root:time step: 70 and window size: 5
# DEBUG:root:23.30823313293513
# DEBUG:root:time step: 71 and window size: 5
# DEBUG:root:24.348219015984796
# DEBUG:root:time step: 72 and window size: 5
# DEBUG:root:23.62528190203011
# DEBUG:root:time step: 73 and window size: 5
# DEBUG:root:24.663123973994516
# DEBUG:root:time step: 74 and window size: 5
# DEBUG:root:23.795105447992682
# DEBUG:root:time step: 75 and window size: 5
# DEBUG:root:23.511110103921965
# DEBUG:root:time step: 76 and window size: 5
# DEBUG:root:23.634691865066998
# DEBUG:root:time step: 77 and window size: 5
# DEBUG:root:23.94212163996417
# DEBUG:root:time step: 78 and window size: 5
# DEBUG:root:23.39490409893915
# DEBUG:root:time step: 79 and window size: 5
# DEBUG:root:23.703177193994634
# DEBUG:root:time step: 80 and window size: 5
# DEBUG:root:24.20914669299964
# DEBUG:root:time step: 81 and window size: 5
# DEBUG:root:24.09679692098871
# DEBUG:root:time step: 82 and window size: 5
# DEBUG:root:24.61234997608699
# DEBUG:root:time step: 83 and window size: 5
# DEBUG:root:24.529079045983963
# DEBUG:root:time step: 84 and window size: 5
# DEBUG:root:23.891339880996384
# DEBUG:root:time step: 85 and window size: 5
# DEBUG:root:23.840875579975545
# DEBUG:root:time step: 86 and window size: 5
# DEBUG:root:23.252050445065834
# DEBUG:root:time step: 87 and window size: 5
# DEBUG:root:24.234677896951325
# DEBUG:root:time step: 88 and window size: 5
# DEBUG:root:23.321913972031325
# DEBUG:root:time step: 89 and window size: 5
# DEBUG:root:23.642310621915385
# DEBUG:root:time step: 90 and window size: 5
# DEBUG:root:24.233369095018134
# DEBUG:root:time step: 91 and window size: 5
# DEBUG:root:23.41217737889383
# DEBUG:root:time step: 92 and window size: 5
# DEBUG:root:23.299508539028466
# DEBUG:root:time step: 93 and window size: 5
# DEBUG:root:22.999064131989144
# DEBUG:root:time step: 94 and window size: 5
# DEBUG:root:24.412904581055045
# DEBUG:root:time step: 95 and window size: 5
# DEBUG:root:23.01271074905526
# DEBUG:root:time step: 96 and window size: 5
# DEBUG:root:23.342472095042467
# DEBUG:root:time step: 97 and window size: 5
# DEBUG:root:24.497336590080522
# DEBUG:root:time step: 98 and window size: 5
# DEBUG:root:23.968389761983417
# DEBUG:root:time step: 99 and window size: 5
# DEBUG:root:23.986235175980255
# DEBUG:root:time step: 100 and window size: 5
# DEBUG:root:23.964419526048005
# DEBUG:root:time step: 101 and window size: 5
# DEBUG:root:24.24843813001644
# DEBUG:root:time step: 102 and window size: 5
# DEBUG:root:24.23465260292869
# DEBUG:root:time step: 103 and window size: 5
# DEBUG:root:25.026655670022592
# DEBUG:root:time step: 104 and window size: 5
# DEBUG:root:23.090519746998325
# DEBUG:root:time step: 105 and window size: 5
# DEBUG:root:23.724473405978642
# DEBUG:root:time step: 106 and window size: 5
# DEBUG:root:23.666056415997446
# DEBUG:root:time step: 107 and window size: 5
# DEBUG:root:24.348025611019693
# DEBUG:root:time step: 108 and window size: 5
# DEBUG:root:24.774037900962867
# DEBUG:root:time step: 109 and window size: 5
# DEBUG:root:24.817019196925685
# DEBUG:root:time step: 110 and window size: 5
# DEBUG:root:24.585044560953975
# DEBUG:root:time step: 111 and window size: 5
# DEBUG:root:23.953049823991023
# DEBUG:root:time step: 112 and window size: 5
# DEBUG:root:24.89712682191748
# DEBUG:root:time step: 113 and window size: 5
# DEBUG:root:23.655308343004435
# DEBUG:root:time step: 114 and window size: 5
# DEBUG:root:23.116468879044987
# DEBUG:root:time step: 115 and window size: 5
# DEBUG:root:23.359020988922566
# DEBUG:root:time step: 116 and window size: 5
# DEBUG:root:23.97068168502301
# DEBUG:root:time step: 117 and window size: 5
# DEBUG:root:24.68367192707956
# DEBUG:root:time step: 118 and window size: 5
# DEBUG:root:24.74905323702842
# DEBUG:root:time step: 119 and window size: 5
# DEBUG:root:24.248907679109834
# DEBUG:root:time step: 120 and window size: 5
# DEBUG:root:23.846861097961664
# DEBUG:root:time step: 121 and window size: 5
# DEBUG:root:23.181721596978605
# DEBUG:root:time step: 122 and window size: 5
# DEBUG:root:24.24955232301727
# DEBUG:root:time step: 123 and window size: 5
# DEBUG:root:23.64936303999275
# DEBUG:root:time step: 124 and window size: 5
# DEBUG:root:24.420384661993012
# DEBUG:root:result len 30

# %%
#### high L1

print(T, N)
print(gamma)
print(L1)
#print(ymean)
#plt.figure(figsize=(30, 10), dpi=100)
y = dax.adj_close["Adj Close"][0:T]
y = y.reshape(T,1,1).flatten()
r = np.diff(y)/y[1:]

l = 30
te = np.zeros(l)

for i in range(l):
    yhat = results[i][-2].flatten()
    rhat = np.diff(yhat)/yhat[1:]
    te[i] = np.std(rhat - r)*sqrt(252)
print(te)
print("Tracking error=%f" % mean(te))

j = 0
for i in range(l):
    if i < j:
        continue
    plt.plot(results[i][-2].flatten(), label=r'$\hat{y}_{50} of run %i$' % i)
    xlabel("t")
    ylabel("y")
    break
    
plt.plot(y.flatten(),'rx', label=r'$y^{ref}$')
savefig("DAXMPC-y-2-125.pdf")
show()
clf()

plt.figure(figsize=(30, 10), dpi=100)
for i in range(l):
    if i < j:
        continue
    print(i)
    plt.plot(results[i][1][:,0,:])
    xlabel("t")
    ylabel("u")
    break
    #break
    
savefig("DAXMPC-u-2-125.pdf")
show()
clf()
# Out:
# 125 10000
# [ 100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.  100.
#   100.  100.  100.  100.  100.]
# [[ 10.   0.   0.   0.   0.   0.]
#  [  0.  10.   0.   0.   0.   0.]
#  [  0.   0.  10.   0.   0.   0.]
#  [  0.   0.   0.  10.   0.   0.]
#  [  0.   0.   0.   0.  10.   0.]
#  [  0.   0.   0.   0.   0.  10.]]
# [ 0.09933022  0.09019074  0.08036151  0.08728082  0.07995668  0.07855594
#   0.08965279  0.08265752  0.08059762  0.08812915  0.08325608  0.08855415
#   0.08028179  0.09217421  0.08051117  0.07745773  0.08844765  0.08064219
#   0.08896781  0.0825886   0.08180165  0.09091218  0.08443876  0.08485478
#   0.09690368  0.07942169  0.08543589  0.08180111  0.08845448  0.08169399]
# Tracking error=0.085177
# 0
